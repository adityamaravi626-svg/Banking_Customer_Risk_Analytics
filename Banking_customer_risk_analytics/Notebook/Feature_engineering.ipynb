# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
bm = pd.read_csv('/content/sample_data/bank_marketing_cleaned (2).csv')

# %%
bm
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
bm.shape
# Out:
# (41188, 22)

# %%
bm.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...    999         0  nonexistent
# 1  cellular   nov         fri  ...    999         0  nonexistent
# 2  cellular   jun         thu  ...      6         2      success
# 3  cellular   apr         fri  ...    999         0  nonexistent
# 4  cellular   aug         fri  ...      3         1      success
#
#    emp_var_rate cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y  \
# 0           1.4         93.444          -36.1      4.963       5228.1  0
# ...

# %%
bm['y'].value_counts()
# Out:
# y
# 0    36548
# 1     4640
# Name: count, dtype: int64

# %%
bm['y'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
bm.isnull().sum()
# Out:
# age                         0
# job                         0
# marital                     0
# education                   0
# default                     0
# housing                     0
# loan                        0
# contact                     0
# month                       0
# day_of_week                 0
# duration                    0
# campaign                    0
# pdays                       0
# previous                    0
# poutcome                    0
# emp_var_rate                0
# cons_price_idx              0
# cons_conf_idx               0
# euribor3m                   0
# nr_employed                 0
# y                       41188
# previously_contacted        0
# dtype: int64

# %%
bm.isnull().sum().sum()
# Out:
# np.int64(41188)

# %%
bm['previously_contacted'] = np.where(
    bm['pdays']==999,
    'no','yes'
)

# %%
bm['previously_contacted'].value_counts()
# Out:
# previously_contacted
# no     39673
# yes     1515
# Name: count, dtype: int64

# %%
bm['pdays'] = bm['pdays'].replace(999,np.nan)

# %%
bm['age_group'] = pd.cut(
    bm['age'],
    bins=[18,25,35,45,55,65,100],
    labels=['18-25','26-35','36-45','46-55','56-65','65+']
)

# %%
bm['age_group'].value_counts().sort_index()
# Out:
# age_group
# 18-25     1633
# 26-35    14847
# 36-45    12844
# 46-55     8249
# 56-65     2963
# 65+        619
# Name: count, dtype: int64

# %%
bm['contact']=pd.cut(
    bm['campaign'],bins=[0,1,3,5,np.inf],
    labels=['low','Moderate','High','Very High']
)

# %%
bm['contact'].value_counts()
# Out:
# contact
# low          17642
# Moderate     15911
# High          4250
# Very High     3385
# Name: count, dtype: int64

# %%
bm['previously_contacted']=np.where(
    bm['previous']>0,'yes','no'
)

# %%
bm['previously_contacted'].value_counts()
# Out:
# previously_contacted
# no     35563
# yes     5625
# Name: count, dtype: int64

# %%
bm.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  previous     poutcome  emp_var_rate  \
# 0       low   aug         thu  ...         0  nonexistent           1.4
# 1       low   nov         fri  ...         0  nonexistent          -0.1
# 2  Moderate   jun         thu  ...         2      success          -1.7
# 3  Moderate   apr         fri  ...         0  nonexistent          -1.8
# 4       low   aug         fri  ...         1      success          -2.9
#
#    cons_price_idx cons_conf_idx  euribor3m  nr_employed   y  \
# ...

# %%
X= bm.drop('y',axis=1)
y= bm['y']

# %%
print('X shape:',X.shape)
print('y shape:',y.shape)
# Out:
# X shape: (41188, 22)
# y shape: (41188,)

# %%
numeric_features = [
    'age',
    'campaign',
    'pdays',
    'previous',
    'emp_var_rate',
    'cons_price_idx',
    'cons_conf_idx',
    'euribor3m',
    'nr_employed'
]

# %%
categorical_features = [
    'job',
    'marital',
    'education',
    'default',
    'housing',
    'loan',
    'contact',
    'month',
    'day_of_week',
    'poutcome',
    'previously_contacted',
    'age_group',
    'contact_intensity',
    'previous_campaign_contact'
]

# %%
print("Numerical:", len(numeric_features))
print("Categorical:", len(categorical_features))
# Out:
# Numerical: 9
# Categorical: 14

# %%
numeric_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]
)

# %%
categorical_transformer= Pipeline(
    steps=[
        ('imputer ', SimpleImputer (strategy='most_frequent')),
        ('onehot',OneHotEncoder(handle_unknown='ignore',sparse_output=False))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
class_distribution = y.value_counts()

# %%
print(
    y.value_counts(normalize=True)*100
)
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
import os

output_dir = 'data'
os.makedirs(output_dir, exist_ok=True)

bm.to_csv(
    os.path.join(output_dir, 'bank_marketing_feature_engineered.csv'),
    index=False
)
